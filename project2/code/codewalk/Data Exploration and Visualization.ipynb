# %% [markdown]
# # Sentiment Analysis - Data Exploration
# ------------------------------------
# ## Initialize Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Import Data

# %%
df=pd.read_json('data/reviews.json.gz',lines=True,compression='gzip')
df.shape
# Out:
# (28798, 9)

# %% [markdown]
# ## Pre-Processing

# %%
df.head()
# Out:
#        reviewerID        asin                          reviewerName   helpful  \
# 0   A6VPK7X53QNAQ  B0000CC64W  AmazonDiva "Keep Calm and Carry On."    [5, 5]
# 1  A3CHMHGSJSQ02J  B0000CC64W                          Anon. A. Non    [2, 2]
# 2  A1V1EP514B5H7Y  B0000CC64W                                asiana    [0, 0]
# 3  A1X2LENOF84LCQ  B0000CC64W                                 D "D"  [62, 75]
# 4  A2PATWWZAXHQYA  B0000CC64W                        Farnoosh Brock    [1, 1]
#
#                                           reviewText  overall  \
# 0  I am a devotee to this serum, it does wonders ...        5
# 1  As a woman nearing 50, I need all the help I c...        5
# 2  I've used this regenerating serum for more tha...        5
# 3  I have tried so many products to just be total...        4
# 4  I love Oil of Olay. My primary moisturizer is ...        1
#
#                                              summary  unixReviewTime  \
# 0  If I had to choose only one product to take ca...      1245283200
# 1                    Makes my skin lovely and smooth      1358467200
# 2                   Works well at a reasonable price      1322524800
# 3                              This does work ladies      1113350400
# 4        Did not like the feel/texture of this serum      1387584000
#
#     reviewTime
# 0  06 18, 2009
# 1  01 18, 2013
# 2  11 29, 2011
# 3  04 13, 2005
# 4  12 21, 2013

# %%
df.isnull().sum()
# Out:
# reviewerID          0
# asin                0
# reviewerName      222
# helpful             0
# reviewText          0
# overall             0
# summary             0
# unixReviewTime      0
# reviewTime          0
# dtype: int64

# %% [markdown]
# We have shown that the dataset has almost 29,000 rows of data and that the only missing data is 222 instances of the reviewer's name, which will have no impact on the results of sentiment analysis. Therefore, we can proceed.

# %% [markdown]
# ## Data Visualizations

# %%
review_length = []

for i in df.reviewText:
    review_length.append(len(i))
    
print('Number of Characters in Each Review')
sns.histplot(x = review_length, bins = 30);
# Out:
# Number of Characters in Each Review

# %%
print('Frequency of Each Rating')
sns.histplot(x = df['overall'], bins = 5);
# Out:
# Frequency of Each Rating

# %% [markdown]
# ## Clean and Process Dataset

# %% [markdown]
# ### Create `y` column for positive/negative sentiment
#
# We chose to include scores 1-3 for `negative` and 4-5 for `positive`.

# %%
df['sentiment'] = np.where(df['overall']>3, 'positive', 'negative')

# %% [markdown]
# Pare down dataset before processing the reviews.

# %%
df1=df[['reviewText','sentiment']]

# %%
df1.shape
# Out:
# (28798, 2)

# %% [markdown]
# ### Formatting the Reviews
# ------------------------
# ### Initialize Libraries

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
# from nltk.cluster import KMeansClusterer
# nltk.download('omw-1.4')
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('words')

import string
import re
import openpyxl
import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %% [markdown]
# ### Processing

# %%
stopword = nltk.corpus.stopwords.words('english')
wn = nltk.WordNetLemmatizer()
ps = nltk.PorterStemmer()
words = set(nltk.corpus.words.words())

# %%
# lower case and remove hyperlinks, stopwords

#create function
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"www.\S+", "", text)
    text_links_removed = " ".join([word for word in re.split('\W+', text)
        if word not in stopword])
    text_cleaned = "".join([char for char in text_links_removed if char not in string.punctuation])
    text = " ".join([wn.lemmatize(word) for word in re.split('\W+', text_cleaned)])

    return text

# apply function
df1['reviewText_lower'] = df1['reviewText'].apply(clean_text)

# visual check
df1.head(5)
# Out:
#                                           reviewText sentiment  \
# 0  I am a devotee to this serum, it does wonders ...  positive
# 1  As a woman nearing 50, I need all the help I c...  positive
# 2  I've used this regenerating serum for more tha...  positive
# 3  I have tried so many products to just be total...  positive
# 4  I love Oil of Olay. My primary moisturizer is ...  negative
#
#                                     reviewText_lower
# 0  devotee serum wonder skin always complimented ...
# 1  woman nearing 50 need help get especially wear...
# 2  used regenerating serum six month found descri...
# 3  tried many product totally disappointed one wo...
# 4  love oil olay primary moisturizer oil olay tot...

# %%
# tokenization from nltk.tokenize

# apply tool
df1.loc[:,'r_lt'] = df1['reviewText_lower'].apply(lambda x : word_tokenize(x))

# visual check
df1.head(5)
# Out:
#                                           reviewText sentiment  \
# 0  I am a devotee to this serum, it does wonders ...  positive
# 1  As a woman nearing 50, I need all the help I c...  positive
# 2  I've used this regenerating serum for more tha...  positive
# 3  I have tried so many products to just be total...  positive
# 4  I love Oil of Olay. My primary moisturizer is ...  negative
#
#                                     reviewText_lower  \
# 0  devotee serum wonder skin always complimented ...
# 1  woman nearing 50 need help get especially wear...
# 2  used regenerating serum six month found descri...
# 3  tried many product totally disappointed one wo...
# 4  love oil olay primary moisturizer oil olay tot...
#
#                                                 r_lt
# 0  [devotee, serum, wonder, skin, always, complim...
# 1  [woman, nearing, 50, need, help, get, especial...
# 2  [used, regenerating, serum, six, month, found,...
# 3  [tried, many, product, totally, disappointed, ...
# 4  [love, oil, olay, primary, moisturizer, oil, o...

# %%
# remove punctuation

def remove_punctuation(token_vector):
    y = [x for x in token_vector if x not in string.punctuation]
    return y

# apply function
df1.loc[:, 'r_ltp'] = df1['r_lt'].apply(remove_punctuation)

# visual check
df1.head(5)
# Out:
#                                           reviewText sentiment  \
# 0  I am a devotee to this serum, it does wonders ...  positive
# 1  As a woman nearing 50, I need all the help I c...  positive
# 2  I've used this regenerating serum for more tha...  positive
# 3  I have tried so many products to just be total...  positive
# 4  I love Oil of Olay. My primary moisturizer is ...  negative
#
#                                     reviewText_lower  \
# 0  devotee serum wonder skin always complimented ...
# 1  woman nearing 50 need help get especially wear...
# 2  used regenerating serum six month found descri...
# 3  tried many product totally disappointed one wo...
# 4  love oil olay primary moisturizer oil olay tot...
#
#                                                 r_lt  \
# 0  [devotee, serum, wonder, skin, always, complim...
# 1  [woman, nearing, 50, need, help, get, especial...
# 2  [used, regenerating, serum, six, month, found,...
# 3  [tried, many, product, totally, disappointed, ...
# 4  [love, oil, olay, primary, moisturizer, oil, o...
#
#                                                r_ltp
# 0  [devotee, serum, wonder, skin, always, complim...
# 1  [woman, nearing, 50, need, help, get, especial...
# 2  [used, regenerating, serum, six, month, found,...
# 3  [tried, many, product, totally, disappointed, ...
# 4  [love, oil, olay, primary, moisturizer, oil, o...

# %%
# convert vectors back into strings
df1['rev_clean'] = df1['r_ltp'].map(lambda x: ' '.join(x))
df1.head(5)
# Out:
#                                           reviewText sentiment  \
# 0  I am a devotee to this serum, it does wonders ...  positive
# 1  As a woman nearing 50, I need all the help I c...  positive
# 2  I've used this regenerating serum for more tha...  positive
# 3  I have tried so many products to just be total...  positive
# 4  I love Oil of Olay. My primary moisturizer is ...  negative
#
#                                     reviewText_lower  \
# 0  devotee serum wonder skin always complimented ...
# 1  woman nearing 50 need help get especially wear...
# 2  used regenerating serum six month found descri...
# 3  tried many product totally disappointed one wo...
# 4  love oil olay primary moisturizer oil olay tot...
#
#                                                 r_lt  \
# 0  [devotee, serum, wonder, skin, always, complim...
# 1  [woman, nearing, 50, need, help, get, especial...
# 2  [used, regenerating, serum, six, month, found,...
# 3  [tried, many, product, totally, disappointed, ...
# 4  [love, oil, olay, primary, moisturizer, oil, o...
#
#                                                r_ltp  \
# 0  [devotee, serum, wonder, skin, always, complim...
# 1  [woman, nearing, 50, need, help, get, especial...
# 2  [used, regenerating, serum, six, month, found,...
# 3  [tried, many, product, totally, disappointed, ...
# 4  [love, oil, olay, primary, moisturizer, oil, o...
#
#                                               r_ltpl  \
# 0  [devotee, serum, wonder, skin, always, complim...
# 1  [woman, nearing, 50, need, help, get, especial...
# 2  [used, regenerating, serum, six, month, found,...
# 3  [tried, many, product, totally, disappointed, ...
# 4  [love, oil, olay, primary, moisturizer, oil, o...
#
#                                            rev_clean
# 0  devotee serum wonder skin always complimented ...
# 1  woman nearing 50 need help get especially wear...
# 2  used regenerating serum six month found descri...
# 3  tried many product totally disappointed one wo...
# 4  love oil olay primary moisturizer oil olay tot...

# %% [markdown]
# ### Word Clouds
#
# All Reviews:

# %%
wdf = df1[['rev_clean', 'sentiment']]
wdf.head(3)
# Out:
#                                            rev_clean sentiment
# 0  devotee serum wonder skin always complimented ...  positive
# 1  woman nearing 50 need help get especially wear...  positive
# 2  used regenerating serum six month found descri...  positive

# %%
text = wdf['rev_clean'].values 

wordcloud = WordCloud(width=800,height=800,background_color='white').generate(str(text))

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Possible additions to stop words: `skin`, `product`.

# %% [markdown]
# Negative Reviews:

# %%
negative_df=wdf[wdf['sentiment']=='negative'].reset_index(drop=True)

# %%
text2 = negative_df['rev_clean'].values 

wordcloud = WordCloud(width=800,height=800,background_color='white').generate(str(text2))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Postive Reviews:

# %%
positive_df=wdf[wdf['sentiment']=='positive'].reset_index(drop=True)

# %%
text2 = positive_df['rev_clean'].values 

wordcloud = WordCloud(width=800,height=800,background_color='white').generate(str(text2))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Possible additions to stop words from positive/negative reviews: `skin`, `product`, `one`.
