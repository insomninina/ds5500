# %% [markdown]
# # Group 2 Codewalk

# %% [markdown]
# ![title.jpg](attachment:title.jpg)

# %% [markdown]
# ## Overview

# %% [markdown]
# ![l-m-r%20goals.jpg](attachment:l-m-r%20goals.jpg)

# %% [markdown]
# ### Project Workflow

# %% [markdown]
# ![flowchart.jpg](attachment:flowchart.jpg)

# %% [markdown]
#  ![embeddings.jpg](attachment:embeddings.jpg)

# %% [markdown]
# ![algorithms.jpg](attachment:algorithms.jpg)
