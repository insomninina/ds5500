# %% [markdown]
# # Sentiment Analysis - Count Vectorizer
# ------------------------------------
# ## Initialize Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Import Data

# %%
# df1.to_csv('data/working_df.csv')
df1=pd.read_csv('data/working_df.csv')

# %% [markdown]
# ### Train-Test Split

# %%
# libraries
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(df1['rev_clean'], df1['sentiment'], test_size=0.20,
                                                    random_state = 40)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (23038,) (5760,) (23038,) (5760,)

# %% [markdown]
# ## Generating TF-IDF Embedding

# %% [markdown]
# ### Initialize Libraries

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Create a Vectorizer Object
vectorizer = CountVectorizer()
 
vectorizer.fit(X_train.astype('U'))
 
# Printing the identified Unique words along with their indices
print("Vocabulary: ", vectorizer.vocabulary_)
 
# Encode the Document
vector = vectorizer.transform(X_train)
 
# Summarizing the Encoded Texts
print("Encoded Document is:")
print(vector.toarray())
# Out:
# Vocabulary:  {'quick': 38461, 'easy': 15731, 'showering': 43230, 'shower': 43197, 'gel': 20293, 'use': 51698, 'bath': 6107, 'sponge': 45405, 'pour': 36716, 'small': 44204, 'amount': 4174, 'onto': 33652, 'laters': 26797, 'easily': 15681, 'last': 26723, 'one': 33466, 'bathing': 6119, 'episodehighly': 16603, 'recommended': 39105, 'buy': 8475, 'product': 37383, 'many': 28938, 'bb': 6194, 'cream': 12081, 'addicted': 3023, 'love': 28309, 'pond': 36481, 'becoming': 6340, 'new': 31717, 'favorite': 18126, 'feel': 18223, 'luxurious': 28525, 'melt': 29457, 'skin': 43682, 'hold': 23309, 'nondrugstore': 32057, 'brand': 7763, 'almost': 3912, 'identical': 24026, 'loreal': 28126, 'except': 17073, 'slightly': 44095, 'le': 26933, 'dewy': 13872, 'actually': 2986, 'prefer': 36873, 'since': 43540, 'already': 3967, 'shine': 42963, 'without': 54255, 'help': 22970, 'anything': 4537, 'wish': 54193, 'spf': 45284, 'bit': 6962, 'higher': 23144, 'office': 32982, 'day': 12973, 'apply': 4777, 'morning': 30814, 'reapply': 38939, 'stepping': 45931, 'outside': 34284, 'lunch': 28486, 'work': 54423, 'great': 21340, 'choice': 9539, 'smooth': 44375, 'gentle': 20413, 'doesnt': 14753, 'dry': 15233, 'ive': 25945, 'purchased': 38224, 'company': 10702, 'specifically': 45228, 'petsafe': 35742, 'floor': 18956, 'cleaning': 9880, 'concentrate': 10948, 'adore': 3118, 'got': 21088, 'apple': 4686, 'lavender': 26894, 'fragrance': 19524, 'free': 19661, 'superb': 47163, 'unlike': 51283, 'antiperspirant': 4463, 'dove': 14938, 'mencare': 29488, 'cool': 11617, 'silver': 43481, 'subtle': 46767, 'smell': 44240, 'irritate': 25367, 'found': 19444, 'excellent': 17060, 'job': 26088, 'preventing': 37070, 'body': 7331, 'odor': 32874, 'good': 20954, 'cutting': 12657, 'eliminating': 16189, 'perspiration': 35697, 'tend': 48025, 'sweat': 47428, 'heavily': 22867, 'may': 29214, 'need': 31558, 'something': 44915, 'stronger': 46464, 'think': 48766, 'perfect': 35467, 'average': 5507, 'man': 28777, 'pretty': 37049, 'people': 35425, 'curly': 12563, 'wavy': 53160, 'hair': 21762, 'keeping': 26299, 'straightened': 46208, 'combination': 10566, 'straightening': 46240, 'additionally': 3038, 'really': 38913, 'nice': 31778, 'however': 23623, 'cause': 9003, 'sticky': 45976, 'feeling': 18239, 'best': 6674, 'take': 47671, 'using': 51989, 'general': 20376, 'okie': 33326, 'im': 24110, 'pleased': 36186, 'wipe': 54148, 'soft': 44699, 'touch': 49873, 'sturdy': 46588, 'enough': 16489, 'put': 38336, 'effort': 16001, 'tearing': 47872, 'nicely': 31810, 'sized': 43626, 'roughly': 40881, '825': 2430, 'inch': 24387, 'inchesit': 24395, 'well': 53519, 'face': 17654, 'hand': 22208, 'clean': 9833, 'leave': 26997, 'appreciable': 4819, 'residue': 39958, 'stickiness': 45965, 'nonirritatingon': 32137, 'downside': 15007, 'cant': 8697, 'say': 41409, 'thrilled': 49073, 'scent': 41582, 'light': 27281, 'odd': 32859, 'sort': 45048, 'botanical': 7535, 'quite': 38568, 'liking': 27490, 'thats': 48279, 'major': 28668, 'problem': 37269, 'dissipates': 14584, 'quicklythe': 38534, 'package': 34768, 'seal': 41940, 'opened': 33706, 'especially': 16690, 'hot': 23486, 'car': 8759, 'better': 6722, 'flap': 18823, 'resealable': 39921, 'pouch': 36705, 'would': 54636, 'nicerecommended': 31841, 'two': 50762, 'reservation': 39939, 'yet': 54950, 'find': 18521, 'eye': 17489, 'makeup': 28689, 'remover': 39728, 'halfway': 22186, 'decently': 13199, 'different': 14028, 'tried': 50307, 'onmaybelline': 33618, 'york': 54993, 'studio': 46521, 'lasting': 26734, 'drama': 15048, 'eyeliner': 17533, 'blackest': 7014, 'blackand': 7009, 'waterproof': 53078, 'mascara': 29043, 'forget': 19297, 'useless': 51872, 'see': 42069, 'uploaded': 51588, 'photo': 35800, 'wiped': 54151, 'folded': 19145, 'half': 22162, 'rubbed': 40939, 'right': 40532, 'remaining': 39646, 'grabbed': 21113, 'eyelash': 17520, 'padand': 34832, 'ughi': 50879, 'still': 46033, 'black': 7006, 'also': 3984, 'make': 28672, 'harder': 22434, 'youd': 55015, 'least': 26978, 'per': 35453, 'sidesif': 43370, 'twoso': 50 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 10
#       7 print("Vocabulary: ", vectorizer.vocabulary_)
#       9 # Encode the Document
# ---> 10 vector = vectorizer.transform(X_train)
#      12 # Summarizing the Encoded Texts
#      13 print("Encoded Document is:")
#
# File ~\anaconda3\envs\ds5500_1\lib\site-packages\sklearn\feature_extraction\text.py:1433, in CountVectorizer.transform(self, raw_documents)
#    1430 self._check_vocabulary()
#    1432 # use the same matrix-building strategy as fit_transform
# -> 1433 _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1434 if self.binary:
#    1435     X.data.fill(1)
#
# File ~\anaconda3\envs\ds5500_1\lib\site-packages\sklearn\feature_extraction\text.py:1275, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1273 for doc in raw_documents:
#    1274     feature_counter = {}
# -> 1275     for feature in analyze(doc):
#    1276         try:
#    1277             feature_idx = vocabulary[feature]
#
# File ~\anaconda3\envs\ds5500_1\lib\site-packages\sklearn\feature_extraction\text.py:106, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      84 """Chain together an optional series of text processing steps to go from
#      85 a single document to ngrams, with or without tokenizing or preprocessing.
#      86
#    (...)
#     102     A sequence of tokens, possibly with pairs, triples, etc.
#     103 """
#     105 if decoder is not None:
# --> 106     doc = decoder(doc)
#     107 if analyzer is not None:
#     108     doc = analyzer(doc)
#
# File ~\anaconda3\envs\ds5500_1\lib\site-packages\sklearn\feature_extraction\text.py:239, in _VectorizerMixin.decode(self, doc)
#     236     doc = doc.decode(self.encoding, self.decode_error)
#     238 if doc is np.nan:
# --> 239     raise ValueError(
#     240         "np.nan is an invalid document, expected byte or unicode string."
#     241     )
#     243 return doc
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %% [markdown]
# ## Generating Models

# %% [markdown]
# ### Initialize Libraries

# %%
import re, string 

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold

# %% [markdown]
# ## Logistic Regression
