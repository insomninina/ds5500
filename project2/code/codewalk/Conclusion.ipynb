# %% [markdown]
# # Conclusion

# %% [markdown]
# -----------------------

# %% [markdown]
# ### Next Steps:
#
# * Complete count vectorizer models
# * Complete multi-class embedding and modeling
# * Compare model performance

# %% [markdown]
# ![references.jpg](attachment:references.jpg)
