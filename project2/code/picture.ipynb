# %%
import pandas as pd 
import seaborn as snsn
import numpy as np

# %%
df = pd.read_csv("df_w_yr.csv")

# %%
df
# Out:
#        Unnamed: 0      reviewerID        asin  \
# 0               0   A6VPK7X53QNAQ  B0000CC64W
# 1               1  A3CHMHGSJSQ02J  B0000CC64W
# 2               2  A1V1EP514B5H7Y  B0000CC64W
# 3               3  A1X2LENOF84LCQ  B0000CC64W
# 4               4  A2PATWWZAXHQYA  B0000CC64W
# ...           ...             ...         ...
# 28793       28793  A3AQHM23X4PCUB  B00L5KTZ0K
# 28794       28794  A1NHB2VC68YQNM  B00L5KTZ0K
# 28795       28795  A1Y3FEUELH3FTI  B00L5KTZ0K
# 28796       28796   AWHZOUIQ0VO7M  B00L5KTZ0K
# 28797       28797  A2I8KUDXTC9WYI  B00L5KTZ0K
#
#                                reviewerName   helpful  \
# 0      AmazonDiva "Keep Calm and Carry On."    [5, 5]
# 1                              Anon. A. Non    [2, 2]
# 2                                    asiana    [0, 0]
# 3                                     D "D"  [62, 75]
# 4                            Farnoosh Brock    [1, 1]
# ...                                     ...       ...
# ...

# %%
data = df.groupby(["year"]).size()
print(data)
# Out:
# year
# 2005        1
# 2007       44
# 2008      674
# 2009      892
# 2010      787
# 2011      843
# 2012     4686
# 2013    11386
# 2014     9485
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data
# Out:
# year
# 2005        1
# 2007       44
# 2008      674
# 2009      892
# 2010      787
# 2011      843
# 2012     4686
# 2013    11386
# 2014     9485
# dtype: int64

# %%
df.groupby('year').value_counts().reset_index(name='t')
# Out:
#        year  Unnamed: 0      reviewerID        asin  \
# 0      2005           3  A1X2LENOF84LCQ  B0000CC64W
# 1      2007           7  A3V6Z4RCDGRC44  B0000CC64W
# 2      2007         635  A3OO4WIO4SKD55  B000UPXU2A
# 3      2007         646  A3E3GD3TABXKU1  B000UPXU2A
# 4      2007         645  A1JAPP1CXRG57A  B000UPXU2A
# ...     ...         ...             ...         ...
# 28568  2014       23978  A2B8GXSCB1R05T  B00GTC1HCI
# 28569  2014       23977   A4D5B7Q8A7PA6  B00GTC1HCI
# 28570  2014       23976  A3LZA698SQPCXE  B00GTC1HCI
# 28571  2014       23975  A1LJR5IS0B6ADX  B00GTC1HCI
# 28572  2014       28797  A2I8KUDXTC9WYI  B00L5KTZ0K
#
#                                            reviewerName   helpful  \
# 0                                                 D "D"  [62, 75]
# 1      Lisa Shea "be the change you wish to see in t...    [6, 7]
# 2                                   I'm hungry. feed me   [6, 11]
# 3                                   Loren w Christensen    [0, 0]
# ...

# %%
a = df.groupby('year').size().reset_index(name='size')

# %%
a
# Out:
#    year   size
# 0  2005      1
# 1  2007     44
# 2  2008    674
# 3  2009    892
# 4  2010    787
# 5  2011    843
# 6  2012   4686
# 7  2013  11386
# 8  2014   9485

# %%
 
 
# who v/s fare barplot
ax= sns.barplot(x = 'year',
            y = 'size',
            data = a)
ax.set(xlabel='year',
       ylabel='Cout of Review ',
       title='Nuper of rating per year')
# Show the plot
plt.show()

# %%
df = pd.read_csv("df_w_yr.csv")

# %%
df['sentiment'] = np.where(df['overall']>3, 'positive', 'negative')

# %%
a=df.groupby(['year','sentiment']).value_counts().reset_index(name='t')

# %%
a = df.groupby(['year','sentiment']).size().reset_index(name='size')

# %%
df2 = df.groupby(['year'])['sentiment'].count()

# %%
a
# Out:
#     year sentiment  size
# 0   2005  positive     1
# 1   2007  negative    16
# 2   2007  positive    28
# 3   2008  negative   183
# 4   2008  positive   491
# 5   2009  negative   238
# 6   2009  positive   654
# 7   2010  negative   209
# 8   2010  positive   578
# 9   2011  negative   260
# 10  2011  positive   583
# 11  2012  negative   927
# 12  2012  positive  3759
# 13  2013  negative  2675
# 14  2013  positive  8711
# 15  2014  negative  1716
# 16  2014  positive  7769

# %%
 
# who v/s fare barplot
ax= sns.barplot(x = 'year',
            y = 'size',
            hue='sentiment',
            data = a)
ax.set(xlabel='year',
       ylabel='Cout of Review ',
       title='Numberer of Rating per year sentntiment')
# Show the plot
plt.show()
