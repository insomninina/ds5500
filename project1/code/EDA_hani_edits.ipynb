# %%
from google.colab import drive
drive.mount('/content/drive')
#CreditCardFraud/amex-default-prediction'
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd CreditCardFraud
# Out:
# /content/drive/MyDrive/CreditCardFraud

# %%
ls
# Out:
#  amex-default-prediction/     'amex-default-prediction.zip (Unzipped Files)'/
#  amex-default-prediction.zip

# %%
cd amex-default-prediction
# Out:
# /content/drive/MyDrive/CreditCardFraud/amex-default-prediction

# %%
ls
# Out:
#  merge_sampled.csv       test_data.csv     'Untitled document.gdoc'
#  sampleddata.csv         train_data.csv
#  sample_submission.csv   train_labels.csv

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib as plt

# %%
ls
# Out:
#  merge_sampled.csv       test_data.csv     'Untitled document.gdoc'
#  sampleddata.csv         train_data.csv
#  sample_submission.csv   train_labels.csv

# %%
#df = pd.DataFrame()
#for chunk in pd.read_csv("train_data.csv", chunksize=1000):
  #df = pd.concat([df, chunk], ignore_index=True)

# %%
df = pd.read_csv("merge_sampled.csv")

# %%
corr = df.corr().abs()

# %%
import matplotlib.pyplot as plt

# %%
mask=np.triu(np.ones_like(corr))

fig, ax = plt.subplots(1,1, figsize=(16,12))
sns.heatmap(corr, ax=ax, mask=mask, cmap='YlOrBr')
ax.set_title("Correlation of features")
plt.show()

# %%
plt.figure(figsize=(16, 5))
sns.countplot(y=df.groupby("customer_ID")["target"].max())
plt.title("Class distribution", fontsize=16)
plt.xlabel("count", fontsize=14)
plt.ylabel("target", fontsize=14);

# %%
ls
# Out:
# sample_data/
