# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
from matplotlib import pyplot as plt

# %%
eda = pickle.load(open("../pickle/eda.pkl", "rb"))
null_hist = pickle.load(open("../pickle/nulls.pkl", "rb"))
cat_features = pickle.load(open("../pickle/cat_features.pkl", "rb"))

# %%
pickle.dump(eda, open("pickle/eda.pkl", "wb"))
pickle.dump(null_hist, open("pickle/nulls.pkl", "wb"))
pickle.dump(cat_features, open("pickle/cat_features.pkl", "wb"))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive
# Out:
# /content/drive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd CreditCardFraud
# Out:
# /content/drive/MyDrive/CreditCardFraud

# %%
cd csv
# Out:
# /content/drive/MyDrive/CreditCardFraud/csv

# %%
eda = pd.read_csv("merge_sampled.csv")

# %% [markdown]
# # Feature Selection
#
# During EDA, we saw that most of the candidate predictor variables contained  < 10% null values. We decided to remove the variables with > 10% null values; the bulk of the variables we are removing are > 90% null values.

# %%
test = pd.DataFrame(eda.isna().sum())

# %%
test.reset_index()
# Out:
#            index      0
# 0    customer_ID      0
# 1            S_2      0
# 2            P_2    786
# 3           D_39      0
# 4            B_1      0
# ..           ...    ...
# 186        D_142  82728
# 187        D_143   1813
# 188        D_144    733
# 189        D_145   1813
# 190       target      0
#
# [191 rows x 2 columns]

# %%
df = test.rename(columns={0: "index", 1: "null_ct"}).reset_index()

# %%
df
# Out:
#          level_0  index
# 0    customer_ID      0
# 1            S_2      0
# 2            P_2    786
# 3           D_39      0
# 4            B_1      0
# ..           ...    ...
# 186        D_142  82728
# 187        D_143   1813
# 188        D_144    733
# 189        D_145   1813
# 190       target      0
#
# [191 rows x 2 columns]

# %%
# make dynamic, change divisor when bigger DS
df['null_pct'] = df['index']/100000 * 100

# %%
df
# Out:
#          level_0  index  null_pct
# 0    customer_ID      0     0.000
# 1            S_2      0     0.000
# 2            P_2    786     0.786
# 3           D_39      0     0.000
# 4            B_1      0     0.000
# ..           ...    ...       ...
# 186        D_142  82728    82.728
# 187        D_143   1813     1.813
# 188        D_144    733     0.733
# 189        D_145   1813     1.813
# 190       target      0     0.000
#
# [191 rows x 3 columns]

# %%
fs_vars = df[df['null_pct'] > 10]

# %%
fs_vars
# Out:
#     level_0  index  null_pct
# 7       S_3  18626    18.626
# 10     D_42  85386    85.386
# 11     D_43  30195    30.195
# 17     D_46  21842    21.842
# 19     D_48  12915    12.915
# 20     D_49  89762    89.762
# 24     D_50  56328    56.328
# 31     D_53  73244    73.244
# 37      S_7  18626    18.626
# 41     D_56  54123    54.123
# 45      S_9  52734    52.734
# 49     D_61  10649    10.649
# 52     D_62  13765    13.765
# 57     B_17  56191    56.191
# 60     D_66  88923    88.923
# 74     D_73  98851    98.851
# 78     D_76  88724    88.724
# 81     D_77  45668    45.668
# 87      R_9  94207    94.207
# 94     D_82  72874    72.874
# 104    B_29  92928    92.928
# 108    D_87  99927    99.927
# 111    D_88  99850    99.850
# 138   D_105  54142    54.142
# 139   D_106  89870    89.870
# 143    R_26  89125    89.125
# 146   D_108  99470    99.470
# 148   D_110  99366    99.366
# 149   D_111  99366    99.366
# 150    B_39  99327    99.327
# 153    S_27  25379    25.379
# 172    B_42  98645    98.645
# 175   D_132  89817    89.817
# 178   D_134  96384    96.384
# 179   D_135  96384    96.384
# 180   D_136  96384    96.384
# 181   D_137  96384    96.384
# 182   D_138  96384    96.384
# 186   D_142  82728    82.728

# %%
fsv = list(fs_vars['level_0'])
fsv
# Out:
# ['S_3',
#  'D_42',
#  'D_43',
#  'D_46',
#  'D_48',
#  'D_49',
#  'D_50',
#  'D_53',
#  'S_7',
#  'D_56',
#  'S_9',
#  'D_61',
#  'D_62',
#  'B_17',
#  'D_66',
#  'D_73',
#  'D_76',
#  'D_77',
#  'R_9',
#  'D_82',
#  'B_29',
#  'D_87',
#  'D_88',
#  'D_105',
#  'D_106',
#  'R_26',
#  'D_108',
#  'D_110',
#  'D_111',
#  'B_39',
#  'S_27',
#  'B_42',
#  'D_132',
#  'D_134',
#  'D_135',
#  'D_136',
#  'D_137',
#  'D_138',
#  'D_142']

# %%
# list of variables we do want
new_v = sorted([f for f in eda.columns if f not in fsv])
new_v
# Out:
# ['B_1',
#  'B_10',
#  'B_11',
#  'B_12',
#  'B_13',
#  'B_14',
#  'B_15',
#  'B_16',
#  'B_18',
#  'B_19',
#  'B_2',
#  'B_20',
#  'B_21',
#  'B_22',
#  'B_23',
#  'B_24',
#  'B_25',
#  'B_26',
#  'B_27',
#  'B_28',
#  'B_3',
#  'B_30',
#  'B_31',
#  'B_32',
#  'B_33',
#  'B_36',
#  'B_37',
#  'B_38',
#  'B_4',
#  'B_40',
#  'B_41',
#  'B_5',
#  'B_6',
#  'B_7',
#  'B_8',
#  'B_9',
#  'D_102',
#  'D_103',
#  'D_104',
#  'D_107',
#  'D_109',
#  'D_112',
#  'D_113',
#  'D_114',
#  'D_115',
#  'D_116',
#  'D_117',
#  'D_118',
#  'D_119',
#  'D_120',
#  'D_121',
#  'D_122',
#  'D_123',
#  'D_124',
#  'D_125',
#  'D_126',
#  'D_127',
#  'D_128',
#  'D_129',
#  'D_130',
#  'D_131',
#  'D_133',
#  'D_139',
#  'D_140',
#  'D_141',
#  'D_143',
#  'D_144',
#  'D_145',
#  'D_39',
#  'D_41',
#  'D_44',
#  'D_45',
#  'D_47',
#  'D_51',
#  'D_52',
#  'D_54',
#  'D_55',
#  'D_58',
#  'D_59',
#  'D_60',
#  'D_63',
#  'D_64',
#  'D_65',
#  'D_68',
#  'D_69',
#  'D_70',
#  'D_71',
#  'D_72',
#  'D_74',
#  'D_75',
#  'D_78',
#  'D_79',
#  'D_80',
#  'D_81',
#  'D_83',
#  'D_84',
#  'D_86',
#  'D_89',
#  'D_91',
#  'D_92',
#  'D_93',
#  'D_94',
#  'D_96',
#  'P_2',
#  'P_3',
#  'P_4',
#  'R_1',
#  'R_10',
#  'R_11',
#  'R_12',
#  'R_13',
#  'R_14',
#  'R_15',
#  'R_16',
#  'R_17',
#  'R_18',
#  'R_19',
#  'R_2',
#  'R_20',
#  'R_21',
#  'R_22',
#  'R_23',
#  'R_24',
#  'R_25',
#  'R_27',
#  'R_28',
#  'R_3',
#  'R_4',
#  'R_5',
#  'R_6',
#  'R_7',
#  'R_8',
#  'S_11',
#  'S_12',
#  'S_13',
#  'S_15',
#  'S_16',
#  'S_17',
#  'S_18',
#  'S_19',
#  'S_2',
#  'S_20',
#  'S_22',
#  'S_23',
#  'S_24',
#  'S_25',
#  'S_26',
#  'S_5',
#  'S_6',
#  'S_8',
#  'customer_ID',
#  'target']

# %%
fs = eda[new_v].copy()

# %%
fs
# Out:
#             B_1      B_10      B_11      B_12      B_13      B_14      B_15  \
# 0      0.008724  0.096219  0.002768  0.148266  0.118075  0.018385  0.016361
# 1      0.004923  0.099804  0.002749  0.143530  0.118737  0.013035  0.017688
# 2      0.021655  0.134073  0.010077  0.137014  0.114534  0.056653  0.063955
# 3      0.013683  0.134437  0.009667  0.129017  0.120740  0.012498  0.022732
# 4      0.015193  0.121518  0.009484  0.129539  0.095178  0.027897  0.031171
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  0.597829  0.018762  0.568745  0.019354  0.008020  0.208935  0.003641
# 99996  0.675999  0.008919  0.644104  0.015428  0.036452  0.205724  0.004038
# 99997  0.645728  0.018506  0.621671  0.015932  0.029023  0.202970  0.007950
# 99998  0.008019  0.016049  0.000656  0.009107  0.007334  0.004305  0.001346
# 99999  0.008796  0.019759  0.006877  0.015071  0.007475  0.002502  0.006494
#
#            B_16      B_18      B_19  ...      S_22      S_23      S_24  \
# 0      0.007665  0.652984  0.008520  ...  0.894090  0.135561  0.911191
# 1      0.007148  0.647093  0.002238  ...  0.902135  0.136333  0.919876
# 2      0.003636  0.645819  0.000408  ...  0.939654  0.134938  0.958699
# 3      0.005896  0.654358  0.005897  ...  0.913205  0.140058  0.926341
# 4      0.001714  0.650112  0.007773  ...  0.921026  0.131620  0.933479
# ...         ...       ...       ...  ...       ...       ...       ...
# 99995  1.007979  0.058000  0.832152  ...  0.927312  0.136109  0.934297
# 99996  1.002550  0.052252  0.915952  ...  0.927598  0.139274  0.934902
# 99997  1.006372  0.060085  1.003033  ...  0.923396  0.137267  0.932529
# 99998  0.172072  0.585668  0.007399  ...  0.296741  0.135450  0.080604
# 99999  0.167976  0.651472  0.006744  ...  0.297361  0.134459  0.081549
#
#            S_25      S_26       S_5       S_6       S_8  \
# 0      0.974539  0.001243  0.023381  0.008322  0.922998
# 1      0.975624  0.004561  0.030599  0.002482  0.919414
# 2      0.974067  0.011736  0.048367  0.000530  1.001977
# 3      0.975499  0.007571  0.030063  0.000783  0.704016
# 4      0.978027  0.018200  0.054221  0.006698  0.917133
# ...         ...       ...       ...       ...       ...
# 99995  0.973335  0.008895  0.003671  1.003519  0.664955
# 99996  0.975162  0.003994  0.004589  0.009121  0.004212
# 99997  0.972051  0.005734  0.005730  0.009046  0.007804
# 99998  0.969829  0.001976  0.001485  1.009798  0.009353
# 99999  0.971570  0.001137  0.003287  1.003678  0.004962
#
#                                              customer_ID  target
# 0      0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 1      0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 2      0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 3      0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 4      0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# ...                                                  ...     ...
# 99995  049dd5e7b5a6895c4f8b179362d8e91f26ebf0b6c95e99...       0
# 99996  049dd5e7b5a6895c4f8b179362d8e91f26ebf0b6c95e99...       0
# 99997  049dd5e7b5a6895c4f8b179362d8e91f26ebf0b6c95e99...       0
# 99998  049e0948e285ec6767bf07e6e3f5e0919821ee200e359d...       0
# 99999  049e0948e285ec6767bf07e6e3f5e0919821ee200e359d...       0
#
# [100000 rows x 152 columns]

# %%
null_test = fs.isna().sum().div(len(eda)).mul(100).sort_values(ascending=False)

# %%
plt.style.use('tableau-colorblind10')
fig, ax = plt.subplots(2,1, figsize=(25,10))
sns.barplot(x=null_test[:100].index, y=null_test[:100].values, ax=ax[0])
sns.barplot(x=null_test[100:].index, y=null_test[100:].values, ax=ax[1])
ax[0].set_ylabel("Percentage [%]"), ax[1].set_ylabel("Percentage [%]")
ax[0].tick_params(axis='x', rotation=90); ax[1].tick_params(axis='x', rotation=90)
plt.suptitle("Missing Data by Candidate Predictors")
plt.tight_layout()
plt.savefig('figs/null_test1.png', dpi=425, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-32a6605e3557> in <module>
#       7 plt.suptitle("Missing Data by Candidate Predictors")
#       8 plt.tight_layout()
# ----> 9 plt.savefig('figs/null_test1.png', dpi=425, bbox_inches='tight')
#      10 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figs/null_test1.png'

# %%
pickle.dump(fs, open("pickle/fs_df.pkl", "wb"))

# %%
fs = pickle.load(open("pickle/fs_df.pkl", "rb"))

# %% [markdown]
# ## Categorical Features
#
# In order to use Scikitlearn PCA, we will drop the categorical variables as well as `S_2`, which is a date/time variable. these will be evaluated separately.

# %%
cat_features
# Out:
# ['B_30',
#  'B_38',
#  'D_114',
#  'D_116',
#  'D_117',
#  'D_120',
#  'D_126',
#  'D_63',
#  'D_64',
#  'D_66',
#  'D_68']

# %%
fs_new = sorted([f for f in fs.columns if f not in cat_features + ['customer_ID','S_2']])
fs_new
# Out:
# ['B_1',
#  'B_10',
#  'B_11',
#  'B_12',
#  'B_13',
#  'B_14',
#  'B_15',
#  'B_16',
#  'B_18',
#  'B_19',
#  'B_2',
#  'B_20',
#  'B_21',
#  'B_22',
#  'B_23',
#  'B_24',
#  'B_25',
#  'B_26',
#  'B_27',
#  'B_28',
#  'B_3',
#  'B_31',
#  'B_32',
#  'B_33',
#  'B_36',
#  'B_37',
#  'B_4',
#  'B_40',
#  'B_41',
#  'B_5',
#  'B_6',
#  'B_7',
#  'B_8',
#  'B_9',
#  'D_102',
#  'D_103',
#  'D_104',
#  'D_107',
#  'D_109',
#  'D_112',
#  'D_113',
#  'D_115',
#  'D_118',
#  'D_119',
#  'D_121',
#  'D_122',
#  'D_123',
#  'D_124',
#  'D_125',
#  'D_127',
#  'D_128',
#  'D_129',
#  'D_130',
#  'D_131',
#  'D_133',
#  'D_139',
#  'D_140',
#  'D_141',
#  'D_143',
#  'D_144',
#  'D_145',
#  'D_39',
#  'D_41',
#  'D_44',
#  'D_45',
#  'D_47',
#  'D_51',
#  'D_52',
#  'D_54',
#  'D_55',
#  'D_58',
#  'D_59',
#  'D_60',
#  'D_65',
#  'D_69',
#  'D_70',
#  'D_71',
#  'D_72',
#  'D_74',
#  'D_75',
#  'D_78',
#  'D_79',
#  'D_80',
#  'D_81',
#  'D_83',
#  'D_84',
#  'D_86',
#  'D_89',
#  'D_91',
#  'D_92',
#  'D_93',
#  'D_94',
#  'D_96',
#  'P_2',
#  'P_3',
#  'P_4',
#  'R_1',
#  'R_10',
#  'R_11',
#  'R_12',
#  'R_13',
#  'R_14',
#  'R_15',
#  'R_16',
#  'R_17',
#  'R_18',
#  'R_19',
#  'R_2',
#  'R_20',
#  'R_21',
#  'R_22',
#  'R_23',
#  'R_24',
#  'R_25',
#  'R_27',
#  'R_28',
#  'R_3',
#  'R_4',
#  'R_5',
#  'R_6',
#  'R_7',
#  'R_8',
#  'S_11',
#  'S_12',
#  'S_13',
#  'S_15',
#  'S_16',
#  'S_17',
#  'S_18',
#  'S_19',
#  'S_20',
#  'S_22',
#  'S_23',
#  'S_24',
#  'S_25',
#  'S_26',
#  'S_5',
#  'S_6',
#  'S_8',
#  'target']

# %%
fs2 = fs[fs_new].copy()

# %%
fs2
# this is what we will use for stepwise selection after imputing NaNs
# Out:
#             B_1      B_10      B_11      B_12      B_13      B_14      B_15  \
# 0      0.008724  0.096219  0.002768  0.148266  0.118075  0.018385  0.016361
# 1      0.004923  0.099804  0.002749  0.143530  0.118737  0.013035  0.017688
# 2      0.021655  0.134073  0.010077  0.137014  0.114534  0.056653  0.063955
# 3      0.013683  0.134437  0.009667  0.129017  0.120740  0.012498  0.022732
# 4      0.015193  0.121518  0.009484  0.129539  0.095178  0.027897  0.031171
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  0.597829  0.018762  0.568745  0.019354  0.008020  0.208935  0.003641
# 99996  0.675999  0.008919  0.644104  0.015428  0.036452  0.205724  0.004038
# 99997  0.645728  0.018506  0.621671  0.015932  0.029023  0.202970  0.007950
# 99998  0.008019  0.016049  0.000656  0.009107  0.007334  0.004305  0.001346
# 99999  0.008796  0.019759  0.006877  0.015071  0.007475  0.002502  0.006494
#
#            B_16      B_18      B_19  ...      S_20      S_22      S_23  \
# 0      0.007665  0.652984  0.008520  ...  0.009705  0.894090  0.135561
# 1      0.007148  0.647093  0.002238  ...  0.009924  0.902135  0.136333
# 2      0.003636  0.645819  0.000408  ...  0.008446  0.939654  0.134938
# 3      0.005896  0.654358  0.005897  ...  0.006614  0.913205  0.140058
# 4      0.001714  0.650112  0.007773  ...  0.005511  0.921026  0.131620
# ...         ...       ...       ...  ...       ...       ...       ...
# 99995  1.007979  0.058000  0.832152  ...  0.002984  0.927312  0.136109
# 99996  1.002550  0.052252  0.915952  ...  0.002146  0.927598  0.139274
# 99997  1.006372  0.060085  1.003033  ...  0.002412  0.923396  0.137267
# 99998  0.172072  0.585668  0.007399  ...  0.006557  0.296741  0.135450
# 99999  0.167976  0.651472  0.006744  ...  0.009537  0.297361  0.134459
#
#            S_24      S_25      S_26       S_5       S_6       S_8  target
# 0      0.911191  0.974539  0.001243  0.023381  0.008322  0.922998       0
# 1      0.919876  0.975624  0.004561  0.030599  0.002482  0.919414       0
# 2      0.958699  0.974067  0.011736  0.048367  0.000530  1.001977       0
# 3      0.926341  0.975499  0.007571  0.030063  0.000783  0.704016       0
# 4      0.933479  0.978027  0.018200  0.054221  0.006698  0.917133       0
# ...         ...       ...       ...       ...       ...       ...     ...
# 99995  0.934297  0.973335  0.008895  0.003671  1.003519  0.664955       0
# 99996  0.934902  0.975162  0.003994  0.004589  0.009121  0.004212       0
# 99997  0.932529  0.972051  0.005734  0.005730  0.009046  0.007804       0
# 99998  0.080604  0.969829  0.001976  0.001485  1.009798  0.009353       0
# 99999  0.081549  0.971570  0.001137  0.003287  1.003678  0.004962       0
#
# [100000 rows x 140 columns]

# %%
fs2.to_csv('data/fs2.csv')

# %%
pickle.dump(fs2, open('data/fs2.pkl', 'wb'))
# fs2 = pickle.load(open('data/fs2.pkl', 'rb'))

# %%
ss = fs2.fillna(fs2.mean())

# %%
pickle.dump(ss, open('data/ss_imputed.pkl', 'wb'))
# ss = pickle.load(open('data/ss_imputed.pkl', 'rb'))

# %%
np.any(np.isnan(ss))
# Out:
# False

# %%
np.all(np.isfinite(ss))
# Out:
# True

# %% [markdown]
# # Low Risk Goal: Stepwise Selection Model

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.decomposition import PCA
from sklearn.feature_selection import chi2

# %%
# prepare the df
X = ss.values
X.shape
# Out:
# (100000, 140)

# %%
# scale the data
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
# transform the data for PCA()
X_scaled = scaler.transform(ss.values)

# %%
# fit the PCA
pca = PCA().fit(ss)

# %%
# plot the cumulative variance
cumulative = np.cumsum(pca.explained_variance_ratio_)

plt.plot(cumulative)
plt.xlabel('Dimensions')
plt.ylabel('Explained Variance')
plt.savefig('figs/cumulative_variance.png', dpi=425, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-5b099a7c7222> in <module>
#       5 plt.xlabel('Dimensions')
#       6 plt.ylabel('Explained Variance')
# ----> 7 plt.savefig('figs/cumulative_variance.png', dpi=425, bbox_inches='tight')
#       8 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figs/cumulative_variance.png'

# %%
# find the elbow
pca2 = PCA(n_components = 0.95)
x_reduced = pca2.fit_transform(ss.values)
x_reduced.shape
# Out:
# (100000, 23)

# %% [markdown]
# Here we see that 23 variables account for 95% of the variation in the data. Therefore, when we do feature selection, we will choose `k=23`.

# %%
data = ss.copy()

X = data.iloc[:,0:138]  #independent columns
y = data.iloc[:,-1]    #target column 


#apply SelectKBest class to extract top 23 best features
bestfeatures = SelectKBest(k=23) # removed param 'score_func=chi2,' due to negative values in the ds
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns

print(featureScores.nlargest(23,'Score'))  #print 23 best features
# Out:
#    Specs         Score
# 93   P_2  59365.810637
# 33   B_9  29778.048588
# 8   B_18  29631.108849
# 10   B_2  27456.940054
# 63  D_44  26035.309480
# 69  D_55  25573.467028
# 79  D_75  25549.993158
# 70  D_58  24347.252963
# 23  B_33  23946.462997
# 78  D_74  20735.053988
# 31   B_7  20320.831893
# 20   B_3  20119.514664
# 14  B_23  19530.237242
# 26   B_4  18560.260921
# 7   B_16  16561.440436
# 0    B_1  16050.781462
# 25  B_37  15656.549636
# 9   B_19  15408.353111
# 96   R_1  15263.559144
# 11  B_20  14793.240020
# 13  B_22  14432.098017
# 2   B_11  14230.835631
# 32   B_8  11376.017450

# %% [markdown]
# We can also visualize this:

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(X,y)
# print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers

#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(23).plot(kind='barh')
plt.savefig('figs/tree_classifier_visualization_ss.png', dpi=425, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-a175960d368d> in <module>
#       8 feat_importances = pd.Series(model.feature_importances_, index=X.columns)
#       9 feat_importances.nlargest(23).plot(kind='barh')
# ---> 10 plt.savefig('figs/tree_classifier_visualization_ss.png', dpi=425, bbox_inches='tight')
#      11 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figs/tree_classifier_visualization_ss.png'

# %%
# heat map

#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=False,cmap="RdYlGn")
plt.savefig('figs/heat_map2.png', dpi=425, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-23ead17cc328> in <module>
#       7 #plot heat map
#       8 g=sns.heatmap(data[top_corr_features].corr(),annot=False,cmap="RdYlGn")
# ----> 9 plt.savefig('figs/heat_map2.png', dpi=425, bbox_inches='tight')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figs/heat_map2.png'

# %% [markdown]
# #hani work

# %%
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import pickle
import time
from sklearn.model_selection import GridSearchCV

# %%
X = data.iloc[:,0:139]  #independent columns
y = data.iloc[:,-1]    #target column

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=data['target'])

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.metrics import accuracy_score

# %%
space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0
    }

# %%
def objective(space):
    clf=XGBClassifier(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']))
    
    evaluation = [( X_train, y_train), ( X_test, y_test)]
    
    clf.fit(X_train, y_train,
            eval_set=evaluation, eval_metric="auc",
            early_stopping_rounds=10,verbose=False)
    

    pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, pred>0.5)
    print ("SCORE:", accuracy)
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# SCORE:
# 0.7617
# SCORE:
# 0.7679
# SCORE:
# 0.7587
# SCORE:
# 0.7666
# SCORE:
# 0.7657
# SCORE:
# 0.7658
# SCORE:
# 0.7665
# SCORE:
# 0.7657
# SCORE:
# 0.7667
# SCORE:
# 0.7648
# SCORE:
# 0.7678
# SCORE:
# 0.7649
# SCORE:
# 0.7658
# SCORE:
# 0.7652
# SCORE:
# 0.7658
# SCORE:
# 0.7654
# SCORE:
# 0.7682
# SCORE:
# 0.7663
# SCORE:
# 0.7648
# SCORE:
# 0.7653
# SCORE:
# 0.7619
# SCORE:
# 0.7663
# SCORE:
# 0.7618
# SCORE:
# 0.7682
# SCORE:
# 0.7659
# SCORE:
# 0.7681
# SCORE:
# 0.762
# SCORE:
# 0.7666
# SCORE:
# 0.7681
# SCORE:
# 0.7658
# SCORE:
# 0.7619
# SCORE:
# 0.767
# SCORE:
# 0.7584
# SCORE:
# 0.768
# SCORE:
# 0.7664
# SCORE:
# 0.7676
# SCORE:
# 0.766
# SCORE:
# 0.7669
# SCORE:
# 0.7658
# SCORE:
# 0.768
# SCORE:
# 0.7682
# SCORE:
# 0.7617
# SCORE:
# 0.7682
# SCORE:
# 0.7666
# SCORE:
# 0.7621
# SCORE:
# 0.7586
# SCORE:
# 0.7658
# SCORE:
# 0.7664
# SCORE:
# 0.7665
# SCORE:
# 0.7681
# SCORE:
# 0.7617
# SCORE:
# 0.7654
# SCORE:
# 0.7659
# SCORE:
# 0.7618
# SCORE:
# 0.7598
# SCORE:
# 0.7658
# SCORE:
# 0.7678
# SCORE:
# 0.7662
# SCORE:
# 0.7669
# SCORE:
# 0.7619
# SCORE:
# 0.766
# SCORE:
# 0.7648
# SCORE:
# 0.7664
# SCORE:
# 0.7617
# SCORE:
# 0.7682
# SCORE:
# 0.768
# SCORE:
# 0.7679
# SCORE:
# 0.7623
# SCORE:
# 0.7679
# SCORE:
# 0.7682
# SCORE:
# 0.7669
# SCORE:
# 0.7679
# SCORE:
# 0.7619
# SCORE:
# 0.7661
# SCORE:
# 0.7679
# SCORE:
# 0.7619
# SCORE:
# 0.7681
# SCORE:
# 0.7656
# SCORE:
# 0.762
# SCORE:
# 0.7662
# SCORE:
# 0.7616
# SCORE:
# 0.7679
# SCORE:
# 0.7666
# SCORE:
# 0.7662
# SCORE:
# 0.768
# SCORE:
# 0.7682
# SCORE:
# 0.7656
# SCORE:
# 0.7642
# SCORE:
# 0.762
# SCORE:
# 0.7652
# SCORE:
# 0.7617
# SCORE:
# 0.7682
# SCORE:
# 0.766
# SCORE:
# 0.7623
# SCORE:
# 0.7658
# SCORE:
# 0.7661
# SCORE:
# 0.7665
# SCORE:
# 0.7662
# SCORE:
# 0.7669
# SCORE:
# 0.7616
# 100%|██████████| 100/100 [11:18<00:00,  6.79s/it, best loss: -0.7682]

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.5535093367114597, 'gamma': 4.537127790284473, 'max_depth': 8.0, 'min_child_weight': 9.0, 'reg_alpha': 52.0, 'reg_lambda': 0.8860343763268222}

# %%
xgb_model = XGBClassifier(colsample_bytree=0.5535093367114597, gamma= 4.537127790284473, max_depth= 8,
                          min_child_weight= 9, reg_alpha=52, reg_lambda= 0.8860343763268222)
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.25,random_state=0)
# %time xgb_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_val, y_val)], verbose=False)
# Out:
# CPU times: user 1min 26s, sys: 158 ms, total: 1min 26s
# Wall time: 1min 35s
# XGBClassifier(colsample_bytree=0.5535093367114597, gamma=4.537127790284473,
#               max_depth=8, min_child_weight=9, reg_alpha=52,
#               reg_lambda=0.8860343763268222)

# %%
from sklearn.metrics import accuracy_score
pred = xgb_model.predict(X_test)
accuracy = accuracy_score(y_test, pred>0.5)
print ("SCORE:", accuracy)
print({'loss': -accuracy, 'status': STATUS_OK })
# Out:
# SCORE: 0.8897
# {'loss': -0.8897, 'status': 'ok'}

# %%
#svm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.svm import SVC
svclassifier = SVC(gamma="auto")
svclassifier.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
from sklearn.metrics import accuracy_score
pred1 = svclassifier.predict(X_test)
accuracy1 = accuracy_score(y_test, pred1>0.5)
print ("SCORE:", accuracy1)
print({'loss': -accuracy1, 'status': STATUS_OK })
# Out:
# SCORE: 0.8733
# {'loss': -0.8733, 'status': 'ok'}
